# %% [markdown]
# #### 1: List the causes of death and percentile in Ohio state in the year 2012

# %%
#import required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#cause of deaths
cause = 'Chronic Diseases', 'Unintentional Injuries', 'Alzhelmers', 'Influenza and Pneumonia', 'Sepsis', 'Others'
#percentile
percentile = [62, 5, 4, 2, 1, 26]

# %% [markdown]
# #### 2: Draw a pie chart using the two data points

# %%
#set the pie chart plot properties

# %%
#set figure size
plt.figure(figsize=(10,10))

# %%
#explode the largest pie in the data set
explode = (0.05, 0, 0, 0, 0,0)

# %%
#set pie chart properties
plt.pie(percentile, labels=cause, explode=explode, autopct='%1.1f%%', startangle=70)
# Out:
# ([<matplotlib.patches.Wedge at 0xc350da0>,
#   <matplotlib.patches.Wedge at 0xc3c6470>,
#   <matplotlib.patches.Wedge at 0xc3c6ba8>,
#   <matplotlib.patches.Wedge at 0xc3d42e8>,
#   <matplotlib.patches.Wedge at 0xc3d4a20>,
#   <matplotlib.patches.Wedge at 0xc3de160>],
#  [Text(-1.14955,-0.0321099,'Chronic Diseases'),
#   Text(0.586164,-0.930812,'Unintentional Injuries'),
#   Text(0.822578,-0.730319,'Alzhelmers'),
#   Text(0.944856,-0.563247,'Influenza and Pneumonia'),
#   Text(0.993669,-0.471829,'Sepsis'),
#   Text(1.01105,0.433336,'Others')],
#  [Text(-0.649747,-0.0181491,'62.0%'),
#   Text(0.319726,-0.507716,'5.0%'),
#   Text(0.448679,-0.398356,'4.0%'),
#   Text(0.515376,-0.307226,'2.0%'),
#   Text(0.542001,-0.257361,'1.0%'),
#   Text(0.551481,0.236365,'26.0%')])

# %%
#set axis equal to draw pie as circle
plt.axis('equal')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
#set title of the pie chart
plt.title('Ohio State-2012:Leading causes of death')
# Out:
# Text(0.5,1,'Ohio State-2012:Leading causes of death')

# %%
#show the plot (pie chart)
plt.show()
